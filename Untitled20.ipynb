# %% [markdown]
# <a href="https://colab.research.google.com/github/haydarsenoll/Neural_Network_DeepLearning/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/data.csv")

# %%
df.head(3)
# Out:
#          id diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0    842302         M        17.99  ...          0.4601                  0.11890          NaN
# 1    842517         M        20.57  ...          0.2750                  0.08902          NaN
# 2  84300903         M        19.69  ...          0.3613                  0.08758          NaN
#
# [3 rows x 33 columns]

# %%
df.drop(['id',"Unnamed: 32"] , axis = 1 , inplace = True)

# %%
M = df[df["diagnosis"] =="M"]
B = df[df["diagnosis"] =="B"]

# %%
plt.scatter(M.radius_mean,M.texture_mean,color = "red",label = "kötü" , alpha= 0.3)
plt.scatter(B.radius_mean,B.texture_mean,color = "green",label = "iyi",alpha = 0.3)
plt.show()

# %%
df['diagnosis']= [1 if each == "M" else 0 for each in df['diagnosis']]

# %%
df
# Out:
#      diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0            1        17.99  ...          0.4601                  0.11890
# 1            1        20.57  ...          0.2750                  0.08902
# 2            1        19.69  ...          0.3613                  0.08758
# 3            1        11.42  ...          0.6638                  0.17300
# 4            1        20.29  ...          0.2364                  0.07678
# ..         ...          ...  ...             ...                      ...
# 564          1        21.56  ...          0.2060                  0.07115
# 565          1        20.13  ...          0.2572                  0.06637
# 566          1        16.60  ...          0.2218                  0.07820
# 567          1        20.60  ...          0.4087                  0.12400
# 568          0         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
X = df.drop(['diagnosis'] , axis = 1)
Y = df['diagnosis']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2 ,random_state = 42)

# %%
SC=StandardScaler()
X_train = SC.fit_transform(X_train)
X_test = SC.transform(X_test)

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(25, activation="relu",input_dim = 30))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.add(tf.keras.layers.Dense(25, activation="relu"))

# %%
ann.add(tf.keras.layers.Dense( 1, activation="sigmoid")) # bu koddaki 1  kaç tane çıkış katmanı olduğunu

# %%
ann.compile(optimizer= "adam" , loss= "binary_crossentropy",metrics = ["accuracy"])

# %%
ann.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4907 - loss: 0.6390
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8879 - loss: 0.4348
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9544 - loss: 0.2844
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9596 - loss: 0.1938
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9705 - loss: 0.1531
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.1242
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9838 - loss: 0.1017
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.1053
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.0798
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9819 - loss: 0.0721
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0780
# Epoch 12/100
# ...

# %%
y_pred = ann.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Y_test_encoded = le.fit_transform(Y_test)
y_pred_encoded = le.transform(y_pred)

cm = confusion_matrix(Y_test_encoded, y_pred_encoded)
print(cm)
print("Accuracy:", accuracy_score(Y_test_encoded, y_pred_encoded))
# Out:
# [[71  0]
#  [ 9 34]]
# Accuracy: 0.9210526315789473
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
